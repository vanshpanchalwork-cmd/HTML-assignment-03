# %% [markdown]
# Question no: 1  Build a simple webpage that displays text as shown in the below image :
#
#  1. This text to be bolded
#  2. This text to be italic
#
#  3. This text to be underlined
#
# 4. This text to be highlighted
#
#  5. This tag is normal text This text is superscript This is normal again
#
# 6. This is a normmal text this text will be subcripted this is normal again
#
# 7. Normal text this is a small text
#
#  8. This text will be deleted

# %%
Answer no 1 : <body>
<b> This text to be bolded </b> <br>
<i> This text to be italic </i> <br>
<ims>  This text to be underlined </ims> <br>
<mark> This text to be highlighted </mark> <br>
This tag is normal text <sup> This text is superscript </sup> This is normal again <br>
This is a normmal text <sub> this text will be subcripted </sub> this is normal again <br>
Normal text <small> this is a small text </small > <br>
    <strike> This text will be deleted </strike> <br>
</body>

# %% [markdown]
# Question no 2 :  Build a simple webpage that helps users navigate different web development-related websites.
#
# Note:
#  On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image :

# %%
<body> Take me to <a href="https://pwskills.com" target="_blank"> PW Skills </a> to buy a course <br>
 Take me to <a href="https://developer.mozilla.org/en-US/" target="_blank"> MDN Docs</a> to know more about web development <br>

Take me to <a href="https://pwskills.com" target="_blank"> PW Skills Lab  </a> to practice live coding
</body>

# %%
Question no 3: Build a simple blog web page with 3 pages home, web development, and web design. Each page must
contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
For the home page you can add some information about yoursel .

# %%
Answer 3 : <body>
    Home  &nbsp;&nbsp;
<a href="https://www.websitegyan.com" target="_blank">  web development </a>
  &nbsp; &nbsp;&nbsp; <a href="https://www.websitegyan.com" target="_blank"> web design </a>"

<h1> Welcome to Website Gyan </h1>
    <P> This website is made to make people aware about web development benefit </P>

    <hr>
</body>

<body>
 web development &nbsp;&nbsp; <a href="https://www.websitegyan.com/webdevelopment " target="_blank"> Web design </a> &nbsp;&nbsp; <a href="https://www.websitegyan.com/home">Home </a>
<h1> Web development is very essential </h1>
<p> Without learning web development a person can't make website </p>
<hr>
</body>

<body >
<a href="https://www.websitegyan.com" target="_blank">  web development </a>
Web Design  Home Web developemt
    </body>

# %% [markdown]
# Question no 4 :  Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag .

# %%
<body> <ol typre="1">
<li> parapgraph tag : paragraphn tag is a non self closing tag . which is used to display paragraph in a website </li>
<li> Bold tag : Bold tag is a  non self closing tag . If you want to display any any text in bold letters then you will use bold tag </li>
<li> Italic tag : If you display any tag in italic style then you will use italic tag </li>
<li> Anchor tag : If you want to insert hyperlinks in your web page then you will use anchor tag </li>
</ol> </body>

# %% [markdown]
#    Question no 5: Create a description list of full stack web development tech stack, using the
#  < dl > tag. Each term should be
# a tech stack name and each description should be a brief explanation of what the tech stack is used for
#
#  Answer 5:

# %%
<body>
The tech stock of full stack  well development are : <BR>
<di> HTML : HTML stands for Hyper Text Markup Language . It is used in front-end development . Html help's us to give structure to the web development </di>
 <BR> <BR> CSS: CSS stands for Cascading Style Sheet . It is used in front-end development to design the web page . It is used to increase the beauty of the web page .
    <BR> <BR>
        <di> Python : Python is used in the back end . It is used to store the data of website & it's user . </di>
</body>

# %% [markdown]
# Question no 6:  Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits.

# %%
Answer 6:
<body>
<table border="10" Cellpadding="30" Cellspacing="20" width="80" height="0">
<big> 1. HTML</big>
<br>
    <tr>
<th> Primary uses case </th> <th> Key feature heading</th>
</tr>
<tr>
<td> Building the structure of web pages </td>
<td> <ol type="1">
    <li> Simple and easy to learn </li>
    <li> Compatible with all web browser </li>
    <li> Allow for semantic make up </li>
</ol></td>
</tr>
</table>
<BR> <BR>
2. CSS
<table border="10" Cellpadding="30" Cellspacing="20" width="80" height="0">
    <tr>
<th> Primary cases </th> <th> Key features </th>
 </tr>
<tr> <td> Styling and layout of web pages </td> <td> <ol type="1"> <li> Allow for seperation of content and presentation </li> <br> <li> Enables responsive design </li> <br> <li> Offers a wide range of styling options </li></td></tr>
</table>

# %% [markdown]
# ![Screenshot (87).png](data:image/png;base64,...)

# %%
Answer 7:
<body>

    <ul type="circle">
        <H1> Table of Content </H1>
        <li> <font color="blue" > <ins> Part 1: Introduction </ins></font> </li>
        <li> <font color="blue"> <ins> Part 2: Getting Started </ins> </font> </ins></li>
          <ul> <li> <font color="blue"> <ins> 2.1 Installing the software </ins> </font> </li>
        <li> <font color="blue"> <ins> Creating a New Project </ins> </font></li>
        <ul> <li> <font color="blue"> <ins> 2.2.1 Project templates </ins></font></li>
            <li> <font color="blue"> <ins> 2.2.2 Customizing settings </ins></font></li> </ul>
            <li> <font color="blue"> <ins> Exploring the interface </ins></font></li>
          <ul> <li> <font color="blue"> <ins> 2.3.1 Toolbar Features </ins></font></li>
<li> <font color="blue"> <ins> 2.3.2 Panel layout </ins></font></li>
<ul> <li> <font color="blue"> <ins> 2.3.2.1 Docking panels  </ins> </li>
<li> <font color="blue"> <ins> 2.3.2.2 Tabbed interface </ins></font></li> </ul> </ul></ul></ul>
<ul> <li> <font color="blue"> <ins> Part 3: Advanced topics </ins></font></li>
<ul> <li> <font color="blue"> <ins> 3.1 working with plugins </ins></font>
<ul> <li> <font color="blue"> <ins> 3.1.1 Installing pulgins </ins></font></li>
    <li> <font color="blue"> <ins> 3.1.2 Plugin configuration </ins></font></li> </ul>
    <li> <font color="blue"> <ins> 3.2 Customizing the UI </ins></font></li>
    <ul> <li> <font color="blue"> <ins> 3.2.1 Changing themes </ins></font></li>
    <li> <font color="blue"> <ins> 3.2.2 Confugiring short cuts </font> </ins></li> </ul>
    <li> <font color="blue"> <ins> 3.3 Optimizing performance </ins></font></li>
    <ul> <li> <font color="blue"> <ins> 3.3.1 Catching strategies </ins></font></li>
 <li> <font color="blue"> <ins>3.3.2 Resource Minification </ins></font></li>  </ul> </ul> </ul>

<ul> <li> <font color="blue"> Part 4: Conclusion </li></ul>

</body>

# %% [markdown]
# ![Screenshot (86).png](data:image/png;base64,...)

# %%
answer 8 :
 <table border="10" cellpadding="15" Cellspacing="15">
<th>
    Conference schedule
</th>
<tr>
    <td> Time </td>
    <td> Room 1 </td>
    <td> Room 2 </td>
    <td> Room 3 </td>
    <td> Room 4 </td>
</tr>
<tr>
    <td> 9:00 AM - 10:00 AM </td>
    <td> Keynote </td>
    <td> Session A</td>
    <td> Session B </td>
    <td rowspan="1.5"> Session C </td>"
</tr>
<tr>
<td> 12:00 pm - 1:00 pm </td>
<td colspan="10"> Lunch break </td>

</tr>
<tr>
  <td> 1:00 PM - 2:00 PM </td> <td> Session G </td> <td> Session H </td> <td> Session L </td> <td> Session J </td>

</tr>

 </table>
